# %%
from pymilvus import Collection, connections, db
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm
import pandas as pd
import numpy as np
import h5py
import time
import os

HOST = os.environ['MILVUS_HOST']
PORT = os.environ['MILVUS_PORT']
USER = os.environ['MILVUS_USER']
PASS = os.environ['MILVUS_PASS']

# %% [markdown]
# Start by loading the reference table and cleaning up some of the columns we want to use. We also need to generate tokens from the ai_description column to support hybrid query experiments.

# %%
df = pd.read_csv('data/photos.tsv000', sep='\t')
df.head()
# Out:
#       photo_id                                photo_url  \
# 0  wud-eV6Vpwo  https://unsplash.com/photos/wud-eV6Vpwo
# 1  psIMdj26lgw  https://unsplash.com/photos/psIMdj26lgw
# 2  2EDjes2hlZo  https://unsplash.com/photos/2EDjes2hlZo
# 3  WN8kSLy8KMQ  https://unsplash.com/photos/WN8kSLy8KMQ
# 4  QAXDmkU60OU  https://unsplash.com/photos/QAXDmkU60OU
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/photo-143924685475...
# 1  https://images.unsplash.com/photo-144077331099...
# 2  https://images.unsplash.com/photo-144683489809...
# 3  https://images.unsplash.com/photo-144530812443...
# 4  https://images.unsplash.com/photo-144196149785...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2015-08-10 22:48:30.841999              t         4273          2392
# 1  2015-08-28 14:49:40.016052              t         3872          2176
# 2  2015-11-06 18:36:17.334458              t         2560          1707
# 3  2015-10-20 02:29:20.267471              t         2288          1520
# 4  2015-09-11 08:51:54.202624              t         2048          1371
#
#    photo_aspect_ratio             photo_description photographer_username  \
# 0                1.79                           NaN           sergio_rola
# 1                1.78                           NaN                 xcvii
# 2                1.50  Sunset reflection over river             imthinhvu
# 3                1.51          Hiking The Mountains               bettenz
# 4                1.49                           NaN                     j
#
#    ... photo_location_country photo_location_city stats_views stats_downloads  \
# 0  ...                    NaN                 NaN     7515660           42055
# 1  ...                    NaN                 NaN     1814817            5893
# 2  ...                    NaN                 NaN     2708347           12420
# 3  ...                    NaN                 NaN     1616448            9773
# 4  ...                    NaN                 NaN      983884            9410
#
#                                       ai_description ai_primary_landmark_name  \
# 0              silhouette of structure under red sky                      NaN
# 1  selective focus photography of black animal ne...                      NaN
# 2     photo of body body of water during golden hour                      NaN
# 3     green leafed trees between two rock formations       Zion National Park
# 4  landscape photography of snow covered mountain...                      NaN
#
#   ai_primary_landmark_latitude ai_primary_landmark_longitude  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                    37.250981                   -112.950525
# 4                          NaN                           NaN
#
#    ai_primary_landmark_confidence                     blur_hash
# 0                             NaN  LJMymdi{1IWo}Gj[w^WVICS#bbS2
# 1                             NaN  LKKd}R^,bJD%~q4Txu%N%gxuD$xu
# 2                             NaN  LeI{]g9u9u%1?KV@s8R-EAf#t5aL
# 3                        65.07215  LoDv=$sjD$bc.AV@ROWCtSn~s:Rj
# 4                             NaN  LUIPMT9F%LoIBax]Rkj]Aet7Rjj[
#
# [5 rows x 31 columns]

# %%
df['stats_views'] = df['stats_views'].fillna(0).astype(int)
df['stats_downloads'] = df['stats_downloads'].fillna(0).astype(int)
df['photo_description'] = df['photo_description'].fillna('').astype(str)
df['ai_description'] = df['ai_description'].fillna('').astype(str)
df['tokens'] = df['ai_description'].str.split()
df.head()
# Out:
#       photo_id                                photo_url  \
# 0  wud-eV6Vpwo  https://unsplash.com/photos/wud-eV6Vpwo
# 1  psIMdj26lgw  https://unsplash.com/photos/psIMdj26lgw
# 2  2EDjes2hlZo  https://unsplash.com/photos/2EDjes2hlZo
# 3  WN8kSLy8KMQ  https://unsplash.com/photos/WN8kSLy8KMQ
# 4  QAXDmkU60OU  https://unsplash.com/photos/QAXDmkU60OU
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/photo-143924685475...
# 1  https://images.unsplash.com/photo-144077331099...
# 2  https://images.unsplash.com/photo-144683489809...
# 3  https://images.unsplash.com/photo-144530812443...
# 4  https://images.unsplash.com/photo-144196149785...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2015-08-10 22:48:30.841999              t         4273          2392
# 1  2015-08-28 14:49:40.016052              t         3872          2176
# 2  2015-11-06 18:36:17.334458              t         2560          1707
# 3  2015-10-20 02:29:20.267471              t         2288          1520
# 4  2015-09-11 08:51:54.202624              t         2048          1371
#
#    photo_aspect_ratio             photo_description photographer_username  \
# 0                1.79                                         sergio_rola
# 1                1.78                                               xcvii
# 2                1.50  Sunset reflection over river             imthinhvu
# 3                1.51          Hiking The Mountains               bettenz
# 4                1.49                                                   j
#
#    ... photo_location_city stats_views stats_downloads  \
# 0  ...                 NaN     7515660           42055
# 1  ...                 NaN     1814817            5893
# 2  ...                 NaN     2708347           12420
# 3  ...                 NaN     1616448            9773
# 4  ...                 NaN      983884            9410
#
#                                       ai_description  \
# 0              silhouette of structure under red sky
# 1  selective focus photography of black animal ne...
# 2     photo of body body of water during golden hour
# 3     green leafed trees between two rock formations
# 4  landscape photography of snow covered mountain...
#
#    ai_primary_landmark_name ai_primary_landmark_latitude  \
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3        Zion National Park                    37.250981
# 4                       NaN                          NaN
#
#   ai_primary_landmark_longitude ai_primary_landmark_confidence  \
# 0                           NaN                            NaN
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                   -112.950525                       65.07215
# 4                           NaN                            NaN
#
#                       blur_hash  \
# 0  LJMymdi{1IWo}Gj[w^WVICS#bbS2
# 1  LKKd}R^,bJD%~q4Txu%N%gxuD$xu
# 2  LeI{]g9u9u%1?KV@s8R-EAf#t5aL
# 3  LoDv=$sjD$bc.AV@ROWCtSn~s:Rj
# 4  LUIPMT9F%LoIBax]Rkj]Aet7Rjj[
#
#                                               tokens
# 0       [silhouette, of, structure, under, red, sky]
# 1  [selective, focus, photography, of, black, ani...
# 2  [photo, of, body, body, of, water, during, gol...
# 3  [green, leafed, trees, between, two, rock, for...
# 4  [landscape, photography, of, snow, covered, mo...
#
# [5 rows x 32 columns]

# %% [markdown]
# We also need to align these data elements to the image vectors we created in 3-encode-images.ipynb. Load the h5py object and merge the two dataframes to ensure ordering remains the same.

# %%
with h5py.File('data/unsplash-lite.hdf5', 'r') as f:
    vectors = np.array(f['unsplash-512']['vectors'])
    fnames = f['unsplash-512']['fnames']
    fnames = np.array([fname.decode('utf-8') for fname in tqdm(fnames)])
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 24999/24999 [00:01<00:00, 18582.92it/s]

# %%
df_vect = pd.DataFrame({'fname':fnames})
df_vect['photo_id'] = df_vect['fname'].map(lambda fname: fname.split('/')[-1][:-4])
df_vect.head()
# Out:
#                                fname     photo_id
# 0  data/unsplash-512/M34IAftLLsY.png  M34IAftLLsY
# 1  data/unsplash-512/0ZHvH8DITFA.png  0ZHvH8DITFA
# 2  data/unsplash-512/c3qvF4WR0Rw.png  c3qvF4WR0Rw
# 3  data/unsplash-512/xXa4h--mrbM.png  xXa4h--mrbM
# 4  data/unsplash-512/TwFZBS0vuV0.png  TwFZBS0vuV0

# %%
df = df_vect.merge(df, on='photo_id', how='left')
df.head()
# Out:
#                                fname     photo_id  \
# 0  data/unsplash-512/M34IAftLLsY.png  M34IAftLLsY
# 1  data/unsplash-512/0ZHvH8DITFA.png  0ZHvH8DITFA
# 2  data/unsplash-512/c3qvF4WR0Rw.png  c3qvF4WR0Rw
# 3  data/unsplash-512/xXa4h--mrbM.png  xXa4h--mrbM
# 4  data/unsplash-512/TwFZBS0vuV0.png  TwFZBS0vuV0
#
#                                  photo_url  \
# 0  https://unsplash.com/photos/M34IAftLLsY
# 1  https://unsplash.com/photos/0ZHvH8DITFA
# 2  https://unsplash.com/photos/c3qvF4WR0Rw
# 3  https://unsplash.com/photos/xXa4h--mrbM
# 4  https://unsplash.com/photos/TwFZBS0vuV0
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/photo-158015067449...
# 1  https://images.unsplash.com/photo-157895114146...
# 2  https://images.unsplash.com/photo-144598606556...
# 3  https://images.unsplash.com/photo-156933405103...
# 4  https://images.unsplash.com/photo-158342657393...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2020-01-27 18:45:03.038748              t         5472          3648
# 1  2020-01-13 21:36:13.695572              t         7360          4912
# 2  2015-10-27 22:48:00.761634              t         4347          2865
# 3  2019-09-24 14:08:09.099339              t         5397          3602
# 4  2020-03-05 16:44:05.731578              t         2574          3504
#
#    photo_aspect_ratio                               photo_description  ...  \
# 0                1.50           Street Photography. Coral Gables. FL.  ...
# 1                1.50             Two waterfalls in Haifoss, Iceland.  ...
# 2                1.52                   Delicate flower on the ground  ...
# 3                1.50                      Cacabelos Spain Lightleaks  ...
# 4                0.73  Elephant with his owner.  www.msblifestyle.com  ...
#
#   photo_location_city stats_views stats_downloads  \
# 0                 NaN      454820            2300
# 1                 NaN      575745            4324
# 2                 NaN     3657652           16675
# 3                 NaN     1059665            5693
# 4                 NaN      372842            2449
#
#                                       ai_description ai_primary_landmark_name  \
# 0             man in black t-shirt riding on bicycle                      NaN
# 1  a large waterfall with a large amount of water...                      NaN
# 2          yellow petaled flower on gray brick floor                      NaN
# 3                               field of green trees                      NaN
# 4  woman in black jacket standing beside elephant...                      NaN
#
#    ai_primary_landmark_latitude ai_primary_landmark_longitude  \
# 0                           NaN                           NaN
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4                           NaN                           NaN
#
#   ai_primary_landmark_confidence                     blur_hash  \
# 0                            NaN  LeLnY[Eg}Y-A;}xFxZs:OXbHRkWV
# 1                            NaN  LSE{U#oy4oM_?w%1M{Rj%MoIWCWr
# 2                            NaN  LFK9Y$0h0o%E$SNFxrai9Ps*?TIb
# 3                            NaN  LuI3,jVEX.0y%1oJR,R*R*fks:jZ
# 4                            NaN  LDCr.hxGIpE10foeNGt7I:E2-o%1
#
#                                               tokens
# 0     [man, in, black, t-shirt, riding, on, bicycle]
# 1  [a, large, waterfall, with, a, large, amount, ...
# 2  [yellow, petaled, flower, on, gray, brick, floor]
# 3                          [field, of, green, trees]
# 4  [woman, in, black, jacket, standing, beside, e...
#
# [5 rows x 33 columns]

# %% [markdown]
# Prep the data for insertion. This is based off of the CollectionSchema we defined in 4-create-collection.ipynb. This easily fits in RAM, but we would probably want a more robust (i.e., less memory-intensive) process for insertion of data in a Production case. Note that this data structure is columnar.

# %%
data = [
    df['photo_id'].values,
    df['photographer_username'].values,
    df['photo_submitted_at'].values,
    df['stats_views'].values,
    df['stats_downloads'].values,
    df['photo_description'].values,
    df['ai_description'].values,
    vectors,
    df['fname'].values,
    [{'tokens':token_list} for token_list in df['tokens']]
]

# %% [markdown]
# Now we can open a connection and start uploading data. We are limited to uploaded chunks less than 1024MB (GraphQL API limitation), so we'll chunk through the data with a batch size of 1000.

# %%
conn = connections.connect(
    user=USER,
    password=PASS,
    host=HOST,
    port=PORT
)

# %%
def get_batches(data, batchsize=1000):
    rowcount = len(data[0]) # This assumes all data is same dimensionality
    batches = []
    for i in range(0, rowcount, batchsize):
        batch = []
        for col in data:
            batch.append(col[i:i+batchsize])
        batches.append(batch)
    return batches

def upload_data_batch(data, collection_name='unsplash_lite'):
    collection = Collection(collection_name)
    response = collection.insert(data)
    return response

data_batches = get_batches(data, batchsize=1000)
with ThreadPoolExecutor(max_workers=8) as executor:
    response = list(tqdm(executor.map(upload_data_batch, data_batches)))
# Out:
# 25it [00:02, 12.48it/s]

# %% [markdown]
# Finally, we can create an Index. Let's stick with FLAT on the float vector (image) field and use Cosine similarity as the distance/similarity metric.

# %%
index_params = {
    "index_type": "FLAT",
    "metric_type": "COSINE",
    "params": {}
}

collection = Collection('unsplash_lite')

collection.create_index(
  field_name="image",
  index_params=index_params,
  index_name="image_cosine"
)
# Out:
# Status(code=0, message=)
